# %% [markdown]
# ## Websearch and visitwebpage agent

# %%
from smolagents import LiteLLMModel, CodeAgent, DuckDuckGoSearchTool, VisitWebpageTool

model = LiteLLMModel(
    model_id="ollama_chat/qwen2:7b",  # Or try other Ollama-supported models
    api_base="http://127.0.0.1:11434",  # Default Ollama local server
    num_ctx=8192,
)

agent = CodeAgent(
    model=model,
    tools=[DuckDuckGoSearchTool(), VisitWebpageTool()],
    additional_authorized_imports=["requests"]
)
system_prompt = """
You are a professional web research assistant. Your primary goal is to find accurate and up-to-date information from the internet in response to user questions.
Always keep in mind the initial question.

You have access to two tools:

- web_search: Use this to search the web and retrieve a list of relevant webpages.
- visit_webpage: Use this to visit a specific webpage URL and extract the relevant content.

When the user asks a question that requires current or external information:
- Use the web_search function to search the web using a precise, relevant query. Review the search results and identify the most credible or relevant URLs.
- Use the visit_webpage function to visit one or more of those URLs to extract accurate information.

Summarize your findings clearly and concisely for the user. If applicable, include the source of your information.

Only use the tools if the answer cannot be deduced from general knowledge or your current context. If you did a web_search, do visit_webpage also. Always prioritize accuracy and clarity in your responses.
"""

question = "What is the favourite dessert of Elisabeth II of United Kingdom?"
prompt="How many studio albums were published by Mercedes Sosa between 2000 and 2009 (included)? You can use the latest 2022 version of english wikipedia."

agent.run(prompt+system_prompt)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ How many studio albums were published by Mercedes Sosa between 2000 and 2009 (included)? You can use the latest │
# │ 2022 version of english wikipedia.                                                                              │
# │ You are a professional web research assistant. Your primary goal is to find accurate and up-to-date information │
# │ from the internet in response to user questions.                                                                │
# │ Always keep in mind the initial question.                                                                       │
# │                                                                                                                 │
# │ You have access to two tools:                                                                                   │
# │                                                                                                                 │
# │ - web_search: Use this to search the web and retrieve a list of relevant webpages.                              │
# │ - visit_webpage: Use this to visit a specific webpage URL and extract the relevant content.                     │
# │                                                                                                                 │
# │ When the user asks a question that requires current or external information:                                    │
# │ - Use the web_search function to search the web using a precise, relevant query. Review the search results and  │
# │ identify the most credible or relevant URLs.                                                                    │
# │ - Use the visit_webpage function to visit one or more of those URLs to extract accurate information.            │
# │                                                                                                                 │
# │ Summarize your findings clearly and concisely for the user. If applicable, include the source of your           │
# │ information.                                                                                                    │
# │                                                                                                                 │
# │ Only use the tools if the answer cannot be deduced from general knowledge or your current context. If you did a │
# │ web_search, do visit_webpage also. Always prioritize accuracy and clarity in your responses.                    │
# │                                                                                                                 │
# ╰─ LiteLLMModel - ollama_chat/qwen2:7b ───────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   query = "Mercedes Sosa studio albums 2000-2009"
#   search_results = web_search(query)
#   print("Search results:", search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Search results: ## Search Results
#
# [Mercedes Sosa - Wikipedia](https://en.wikipedia.org/wiki/Mercedes_Sosa)
# Haydée Mercedes "La Negra" Sosa (Latin American Spanish: [meɾˈseðes ˈsosa]; 9 July 1935 [1] - 4 October 2009) was
# an Argentine singer who was popular throughout Latin America and many countries outside the region. With her roots
# in Argentine folk music, Sosa became one of the preeminent exponents of El nuevo cancionero.She gave voice to songs
# written by many Latin American songwriters.
#
# [Mercedes Sosa Discography, Complete list of albums by ... -
# FamousFix](https://www.famousfix.com/topic/mercedes-sosa/albums)
# Full list of Mercedes Sosa albums, sorted by release date. You can also sort the list of albums by most recently
# added, year recorded (from most recent to first recorded), by views and by album name. ... Studio Album 2009.
# Cantora 2. Studio Album 2009. Acustico en Suiza Inedito. Studio Album 2009. See also Mercedes Sosa Songs | Mercedes
# Sosa ...
#
# [Mercedes Sosa Discography: Vinyl, CDs, & More | Discogs](https://www.discogs.com/artist/333361-Mercedes-Sosa)
# Explore Mercedes Sosa's biography, discography, and artist credits. ... Shop rare vinyl records, top albums, and
# more on Discogs. Everything Releases Artists Labels. View all results. Explore. Discover. ... known as La Negra,
# (born July 9, 1935 in San Miguel de Tucuman, Argentina - Death October 4, 2009 in Buenos Aires) was an Argentine
# ...
#
# [Mercedes Sosa Albums, Songs - Discography - Album of The
# Year](https://www.albumoftheyear.org/artist/33792-mercedes-sosa/)
# Information on Mercedes Sosa. Complete discography, ratings, reviews and more.
#
# [Mercedes Sosa Discography](https://www.mercedes-sosa.com/discographie)
# Find all Mercedes Sosa's cd's in chronological order here and listen to other Latin American artists I discovered
# through Mercedes Sosa. Find inspiration from world music more generally. ... (2000) Acústico (2002) Argentina
# quiere cantar (2003) (con Víctor Heredia & León Gieco) Corazón libre (2005) Cantora (2009) Posthum veröffentliche
# ...
#
# [Category:Mercedes Sosa albums - Wikipedia](https://en.wikipedia.org/wiki/Category:Mercedes_Sosa_albums)
# This is a set category.It should only contain pages that are Mercedes Sosa albums or lists of Mercedes Sosa albums,
# as well as subcategories containing those things (themselves set categories). Topics about Mercedes Sosa albums in
# general should be placed in relevant topic categories
#
# [Mercedes Sosa Albums: songs, discography, biography, and listening
# ...](https://rateyourmusic.com/artist/mercedes-sosa)
# Mercedes Sosa discography and songs: Music profile for Mercedes Sosa, born 9 July 1935. Genres: Nuevo Cancionero,
# Hispanic American Folk Music, Nueva canción latinoamericana. Albums include Geraes, Mercedes Sosa en Argentina, and
# Canciones con fundamento. ... Born. 9 July 1935, San Miguel de Tucumán, Tucumán, Argentina. Died. 4 October 2009
# ...
#
# [Mercedes Sosa Albums and Discography - Genius](https://genius.com/artists/Mercedes-sosa/albums)
# See all of Mercedes Sosa's albums on Genius. Music IQ Featured Charts Videos Promote Your Music. Sign Up. Mercedes
# Sosa. Mercedes Sosa Albums. ... January 1, 2009. Corazón Libre. 2005.
#
# [Mercedes Sosa - The Best Of Mercedes Sosa | Releases -
# Discogs](https://www.discogs.com/master/1070701-Mercedes-Sosa-The-Best-Of-Mercedes-Sosa)
# Explore the tracklist, credits, statistics, and more for The Best Of Mercedes Sosa by Mercedes Sosa. Compare
# versions and buy on Discogs
#
# [Discographie de Mercedes Sosa - Allformusic](https://www.allformusic.fr/mercedes-sosa/discographie)
# La discographie de Mercedes Sosa est composée de 104 oeuvres dont 42 albums enregistrés en studio à écouter et
# regarder gratuitement. Allformusic. Nouveautés; Albums; Artistes; ... Canción con Todos 2009. Argentina quiere
# cantar 2003. Acústico en vivo 2002. Live in Europe 1989.
#
# Out: None
# [Step 1: Duration 7.12 seconds| Input tokens: 2,353 | Output tokens: 100]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   url = "https://en.wikipedia.org/wiki/Mercedes_Sosa"
#   webpage_content = visit_webpage(url)
#   print(webpage_content)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Mercedes Sosa - Wikipedia
#
# [Jump to content](#bodyContent)
#
# Main menu
#
# Main menu
#
# move to sidebar
# hide
#
# Navigation
#
# * [Main page](/wiki/Main_Page "Visit the main page [z]")
# * [Contents](/wiki/Wikipedia:Contents "Guides to browsing Wikipedia")
# * [Current events](/wiki/Portal:Current_events "Articles related to current events")
# * [Random article](/wiki/Special:Random "Visit a randomly selected article [x]")
# * [About Wikipedia](/wiki/Wikipedia:About "Learn about Wikipedia and how it works")
# * [Contact us](//en.wikipedia.org/wiki/Wikipedia:Contact_us "How to contact Wikipedia")
#
# Contribute
#
# * [Help](/wiki/Help:Contents "Guidance on how to use and edit Wikipedia")
# * [Learn to edit](/wiki/Help:Introduction "Learn how to edit Wikipedia")
# * [Community portal](/wiki/Wikipedia:Community_portal "The hub for editors")
# * [Recent changes](/wiki/Special:RecentChanges "A list of recent changes to Wikipedia [r]")
# * [Upload file](/wiki/Wikipedia:File_upload_wizard "Add images or other media for use on Wikipedia")
# * [Special pages](/wiki/Special:SpecialPages)
#
# [![](/static/images/icons/wikipedia.png)
#
# ![Wikipedia](/static/images/mobile/copyright/wikipedia-wordmark-en.svg)
# ![The Free Encyclopedia](/static/images/mobile/copyright/wikipedia-tagline-en.svg)](/wiki/Main_Page)
#
# [Search](/wiki/Special:Search "Search Wikipedia [f]")
#
# Search
#
# Appearance
#
# *
# [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=e
# n)
# * [Create account](/w/index.php?title=Special:CreateAccount&returnto=Mercedes+Sosa "You are encouraged to create an
# account and log in; however, it is not mandatory")
# * [Log in](/w/index.php?title=Special:UserLogin&returnto=Mercedes+Sosa "You're encouraged to log in; however, it's
# not mandatory. [o]")
#
# Personal tools
#
# *
# [Donate](https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=e
# n)
# * [Create account](/w/index.php?title=Special:CreateAccount&returnto=Mercedes+Sosa "You are encouraged to create an
# account and log in; however, it is not mandatory")
# * [Log in](/w/index.php?title=Special:UserLogin&returnto=Mercedes+Sosa "You're encouraged to log in; however, it's
# not mandatory. [o]")
#
# Pages for logged out editors [learn more](/wiki/Help:Introduction)
#
# * [Contributions](/wiki/Special:MyContributions "A list of edits made from this IP address [y]")
# * [Talk](/wiki/Special:MyTalk "Discussion about edits from this IP address [n]")
#
# Contents
# --------
#
# move to sidebar
# hide
#
# * [(Top)](#)
# * [1
#   Life](#Life)
# * [2
#   Awards](#Awards)
# * [3
#   Death](#Death)
# * [4
#   Tributes](#Tributes)
# * [5
#   Discography](#Discography)
#
#   Toggle Discography subsection
#   + [5.1
#     Studio albums](#Studio_albums)
#   + [5.2
#     EPs](#EPs)
#   + [5.3
#     Live albums](#Live_albums)
#   + [5.4
#     Compilation albums](#Compilation_albums)
# * [6
#   Filmography](#Filmography)
# * [7
#   Further reading](#Further_reading)
# * [8
#   References](#References)
# * [9
#   External links](#External_links)
#
# Toggle the table of contents
#
# Mercedes Sosa
# =============
#
# 49 languages
#
# * [العربية](https://ar.wikipedia.org/wiki/%D9%85%D8%B1%D8%B3%D9%8A%D8%AF%D8%B3_%D8%B3%D9%88%D8%B3%D8%A7 "مرسيدس
# سوسا – Arabic")
# * [Aymar aru](https://ay.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa –
wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Hungarian")
# *
# [മലയാളം](https://ml.wikipedia.org/wiki/%E0%B4%AE%E0%B5%86%E0%B4%B4%E0%B5%8D%E2%80%8C%E0%B4%B8%E0%B4%BF%E0%B4%A1%E0%B4
# %B8%E0%B5%8D_%E0%B4%B8%E0%B5%8B%E0%B4%B8 "മെഴ്‌സിഡസ് സോസ – Malayalam")
# * [مصرى](https://arz.wikipedia.org/wiki/%D9%85%D8%B1%D8%B3%D9%8A%D8%AF%D8%B3_%D8%B3%D9%88%D8%B3%D8%A7 "مرسيدس سوسا
# – Egyptian Arabic")
# * [Nederlands](https://nl.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Dutch")
# *
# [日本語](https://ja.wikipedia.org/wiki/%E3%83%A1%E3%83%AB%E3%82%BB%E3%83%87%E3%82%B9%E3%83%BB%E3%82%BD%E3%83%BC%E3%
# 82%B5 "メルセデス・ソーサ – Japanese")
# * [Norsk bokmål](https://no.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Norwegian Bokmål")
# * [Occitan](https://oc.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Occitan")
# * [Polski](https://pl.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Polish")
# * [Português](https://pt.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Portuguese")
# * [Runa Simi](https://qu.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Quechua")
# *
# [Русский](https://ru.wikipedia.org/wiki/%D0%A1%D0%BE%D1%81%D0%B0,_%D0%9C%D0%B5%D1%80%D1%81%D0%B5%D0%B4%D0%B5%D1%81
# "Соса, Мерседес – Russian")
# * [Scots](https://sco.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Scots")
# * [Simple English](https://simple.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Simple English")
# * [Slovenščina](https://sl.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Slovenian")
# * [Suomi](https://fi.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Finnish")
# * [Svenska](https://sv.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Swedish")
# * [Tagalog](https://tl.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Tagalog")
# * [Türkçe](https://tr.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Turkish")
# *
# [Українська](https://uk.wikipedia.org/wiki/%D0%9C%D0%B5%D1%80%D1%81%D0%B5%D0%B4%D0%B5%D1%81_%D0%A1%D0%BE%D1%81%D0%B
# 0 "Мерседес Соса – Ukrainian")
# * [Tiếng Việt](https://vi.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Vietnamese")
# * [Zazaki](https://diq.wikipedia.org/wiki/Mercedes_Sosa "Mercedes Sosa – Dimli")
# * [中文](https://zh.wikipedia.org/wiki/%E6%A2%85%E8%B3%BD%E5%BE%B7%E6%96%AF%C2%B7%E7%B4%A2%E8%96%A9 "梅賽德斯·索薩
# – Chinese")
#
# [Edit links](https://www.wikidata.org/wiki/Special:EntityPage/Q216450#sitelinks-wikipedia "Edit interlanguage
# links")
#
# * [Article](/wiki/Mercedes_Sosa "View the content page [c]")
# * [Talk](/wiki/Talk:Mercedes_Sosa "Discuss improvements to the content page [t]")
#
# English
#
# * [Read](/wiki/Mercedes_Sosa)
# * [Edit](/w/index.php?title=Mercedes_Sosa&action=edit "Edit this page [e]")
# * [View history](/w/index.php?title=Mercedes_Sosa&action=history "Past revisions of this page [h]")
#
# Tools
#
# Tools
#
# move to sidebar
# hide
#
# Actions
#
# * [Read](/wiki/Mercedes_Sosa)
# * [Edit](/w/index.php?title=Mercedes_Sosa&action=edit "Edit this page [e]")
# * [View history](/w/index.php?title=Mercedes_Sosa&action=history)
#
# General
#
# * [What links here](/wiki/Special:WhatLinksHere/Mercedes_Sosa "List of all English Wikipedia pages containing links
# to this page [j]")
# * [Related changes](/wiki/Special:RecentChangesLinked/Mercedes_Sosa "Recent changes in pages linked from this page
# [k]")
# * [Upload file](//en.wikipedia.org/wiki/Wikipedia:File_Upload_Wizard "Upload files [u]")
# * [Permanent link](/w/index.php?title=Mercedes_Sosa&oldid=1294833034 "Permanent link to this revision of this
# page")
# * [Page information](/w/index.php?title=Mercedes_Sosa&action=info "More information about this page")
# * [Cite this
# page](/w/index.php?title=Special:CiteThisPage&page=Mercedes_Sosa&id=1294833034&wpFormIdentifier=titleform
# "Information on how to cite this page")
# * [Get shortened
# URL](/w/index.php?title=Special:UrlShortener&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FMercedes_Sosa)
# * [Download QR code](/w/index.php?title=Special:QrCode&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FMercedes_Sosa)
#
# Print/export
#
# * [Download as PDF](/w/index.php?title=Special:DownloadAsPdf&page=Mercedes_Sosa&action=show-download-screen
# "Download this page as a PDF file")
# * [Printable version](/w/index.php?title=Mercedes_Sosa&printable=yes "Printable version of this page [p]")
#
# In other projects
#
# * [Wikimedia Commons](https://commons.wikimedia.org/wiki/Category:Mercedes_Sosa)
# * [Wikidata item](https://www.wikidata.org/wiki/Special:EntityPage/Q216450 "Structured data on this page hosted by
# Wikidata [g]")
#
# Appearance
#
# move to sidebar
# hide
#
# From Wikipedia, the free encyclopedia
#
# Argentine singer (1935–2009)
#
# Not to be confused with [Mercedes Sola](/wiki/Mercedes_Sola "Mercedes Sola").
#
# | Mercedes Sosa | |
# | --- | --- |
# | Portrait by [Annemarie Heinrich](/wiki/Annemarie_Heinrich "Annemarie Heinrich"), 1960s | |
# | Born | Haydée Mercedes Sosa  (1935-07-09)9 July 1935  [San Miguel de Tucumán](/wiki/San_Miguel_de_Tucum%C3%A1n
# "San Miguel de Tucumán"), Tucumán, Argentina |
# | Died | 4 October 2009(2009-10-04) (aged 74)  [Buenos Aires](/wiki/Buenos_Aires "Buenos Aires"), Argentina |
# | Occupation | Singer |
# | Years active | 1950–2009 |
# | **Musical career** | |
# | Genres | * [Folk](/wiki/Folk_music "Folk music") * [nueva canción](/wiki/Nueva_canci%C3%B3n "Nueva canción") |
# | Instruments | Vocals |
# | Musical artist | |
#
# **Haydée Mercedes** "**La Negra**" **Sosa** (Latin American Spanish: [[meɾˈseðes ˈsosa]](/wiki/Help:IPA/Spanish
# "Help:IPA/Spanish"); 9 July 1935[[1]](#cite_note-birth-1) – 4 October 2009) was an [Argentine](/wiki/Argentines
# "Argentines") singer who was popular throughout [Latin America](/wiki/Latin_America "Latin America") and many
# countries outside the region. With her roots in [Argentine folk music](/wiki/Folk_music_of_Argentina "Folk music of
# Argentina"), Sosa became one of the preeminent exponents of *El nuevo cancionero*. She gave voice to songs written
# by many Latin American songwriters. Her music made people hail her as the "voice of the voiceless
# ones".[[2]](#cite_note-tmc-2) She was often called "the conscience of Latin America".[[3]](#cite_note-Heckman-3)
#
# Sosa performed in venues such as the [Lincoln Center](/wiki/Lincoln_Center "Lincoln Center") in New York City, the
# [Théâtre Mogador](/wiki/Th%C3%A9%C3%A2tre_Mogador "Théâtre Mogador") in Paris, the [Sistine
# Chapel](/wiki/Sistine_Chapel "Sistine Chapel") in Vatican City, as well as sold-out shows in New York's [Carnegie
# Argentina).[[9]](#cite_note-Latin_artist_Mercedes_Sosa_dies-9) Her second record was *Canciones con Fundamento*, a
# collection of Argentine folk songs.
#
# [![](//upload.wikimedia.org/wikipedia/commons/thumb/d/d8/Mercedes_Sosa%2C_F%C3%A9lix_Luna_y_Ariel_Ram%C3%ADrez.jpg/
# 250px-Mercedes_Sosa%2C_F%C3%A9lix_Luna_y_Ariel_Ram%C3%ADrez.jpg)](/wiki/File:Mercedes_Sosa,_F%C3%A9lix_Luna_y_Ariel
# _Ram%C3%ADrez.jpg)
#
# Sosa with [Félix Luna](/wiki/F%C3%A9lix_Luna "Félix Luna") and [Ariel Ramírez](/wiki/Ariel_Ram%C3%ADrez "Ariel
# Ramírez") (at the piano)
#
# Sosa "spent the late 1960s building her audience in Europe and among the cosmopolitan middle class in Buenos Aires,
# becoming in the process a much bigger star" than her contemporaries.[[10]](#cite_note-10) In 1967, Sosa toured the
# United States and Europe with great success.[*[citation needed](/wiki/Wikipedia:Citation_needed "Wikipedia:Citation
# needed")*] In later years, she performed and recorded extensively, broadening her repertoire to include material
# from throughout Latin America.
#
# In the early 1970s, Sosa released two concept albums in collaboration with composer [Ariel
# Ramírez](/wiki/Ariel_Ram%C3%ADrez "Ariel Ramírez") and lyricist [Félix Luna](/wiki/F%C3%A9lix_Luna "Félix Luna"):
# *Cantata Sudamericana* and *Mujeres Argentinas* (Argentine Women). She also recorded a tribute to Chilean musician
# [Violeta Parra](/wiki/Violeta_Parra "Violeta Parra") in 1971, including what was to become one of Sosa's signature
# songs, *[Gracias a la vida](/wiki/Gracias_a_la_vida "Gracias a la
# vida")*.[[4]](#cite_note-Legendary_folk_singer_Mercedes_Sosa_dies_at_74-4)[[11]](#cite_note-ap-11) She further
# popularized of songs written by [Milton Nascimento](/wiki/Milton_Nascimento "Milton Nascimento") of Brazil and
# [Pablo Milanés](/wiki/Pablo_Milan%C3%A9s "Pablo Milanés") and [Silvio Rodríguez](/wiki/Silvio_Rodr%C3%ADguez
# "Silvio Rodríguez") both from [Cuba](/wiki/Cuba
# "Cuba").[[4]](#cite_note-Legendary_folk_singer_Mercedes_Sosa_dies_at_74-4) Throughout the decade, she released
# albums such as *Hasta la Victoria* in 1972 and *Traigo un Pueblo* *en mi Voz* in 1973. They featured songs like
# "Cuando tenga la tierra", written by [Ariel Petrocelli](/w/index.php?title=Ariel_Petrocelli&action=edit&redlink=1
# "Ariel Petrocelli (page does not exist)") and Daniel Toro, which tackles political and social issues like wealth
# and land inequality.[[12]](#cite_note-:2-12)[[13]](#cite_note-13) During the 1970s she was a part of two films by
# the director [Leopoldo Torre Nilsson](/wiki/Leopoldo_Torre_Nilsson "Leopoldo Torre Nilsson"): *[El Santo de la
# Espada](/wiki/El_Santo_de_la_Espada "El Santo de la Espada")* in 1970 and *[Güemes, la tierra en
# armas](/wiki/G%C3%BCemes:_la_tierra_en_armas "Güemes: la tierra en armas")* in 1971, in which she portrayed [Juana
# Azurduy de Padilla](/wiki/Juana_Azurduy_de_Padilla "Juana Azurduy de Padilla"), the guerrilla military leader who
# fought for Argentine independence.[[12]](#cite_note-:2-12)[[14]](#cite_note-14)
#
# [![](//upload.wikimedia.org/wikipedia/commons/thumb/6/65/Mercedes_Sosa_2.jpg/250px-Mercedes_Sosa_2.jpg)](/wiki/File
# :Mercedes_Sosa_2.jpg)
#
# Sosa in 1972
#
# After the [military junta](/wiki/National_Reorganization_Process "National Reorganization Process") of [Jorge
# Videla](/wiki/Jorge_Videla "Jorge Videla") came to power in 1976, the atmosphere in Argentina grew increasingly
# oppressive. Sosa faced death threats against both her and her family, but refused for many years to leave the
# country. At a concert in [La Plata](/wiki/La_Plata "La Plata") in 1979, Sosa was searched and arrested on stage,
# along with all those attending the concert.[[9]](#cite_note-Latin_artist_Mercedes_Sosa_dies-9) Their release came
# about through international intervention.[[7]](#cite_note-Mercedes_Sosa:_Obituary-7) Despite attempts to hold more
# concerts, she was officially barred from performing by the military regime.[[5]](#cite_note-:0-5) Banned in her own
# country, she moved to Paris and then to [Madrid](/wiki/Madrid
# "Madrid").[[7]](#cite_note-Mercedes_Sosa:_Obituary-7)[[9]](#cite_note-Latin_artist_Mercedes_Sosa_dies-9) She has
# spoken publicly about her artistic and emotional struggles during this period of her life.[[5]](#cite_note-:0-5)
# While in exile, she released the album *A Quien Doy* in 1981. The album included a recording of the song "Cuando Me
# Acuerdo de Mi Pais" which was originally written by the prolific Chilean singer/songwriter, [Patricio
# Manns](/wiki/Patricio_Manns "Patricio Manns"). The song, which he wrote while also in political exile, expresses
# the sorrow he felt from being separated from his homeland.[[15]](#cite_note-15) She related to this feeling and
# struggled to continue recording and performing. In an interview with the New York Times, she said, “It was a mental
# problem, a problem of morale...
# ..._This content has been truncated to stay below 40000 characters_...
# Thiago Soares](/wiki/Thiago_Soares "Thiago Soares") * [Trio
# Roraimeira](/w/index.php?title=Trio_Roraimeira&action=edit&redlink=1 "Trio Roraimeira (page does not exist)") * [Vó
# Mera](/w/index.php?title=V%C3%B3_Mera&action=edit&redlink=1 "Vó Mera (page does not exist)") * [Wanda
# Sá](/wiki/Wanda_S%C3%A1 "Wanda Sá") |
# | 2019–2024 | *Not awarded* |
# | 2025 | * [Alaíde Costa](/wiki/Ala%C3%ADde_Costa "Alaíde Costa") * [Alceu Valença](/wiki/Alceu_Valen%C3%A7a "Alceu
# Valença") * [Aldir Blanc](/wiki/Aldir_Blanc "Aldir Blanc") * [Alcione](/wiki/Alcione_Nazareth "Alcione Nazareth") *
# [Tony Tornado](/wiki/Tony_Tornado "Tony Tornado") * [Arlindo Cruz](/wiki/Arlindo_Cruz "Arlindo Cruz") * [Ary
# Fontoura](/wiki/Ary_Fontoura "Ary Fontoura") * [Dom Filó](/w/index.php?title=Dom_Fil%C3%B3&action=edit&redlink=1
# "Dom Filó (page does not exist)") * [Danilo Santos de
# Miranda](/w/index.php?title=Danilo_Santos_de_Miranda&action=edit&redlink=1 "Danilo Santos de Miranda (page does not
# exist)") * [Xororó](/wiki/Chit%C3%A3ozinho_%26_Xoror%C3%B3 "Chitãozinho & Xororó") * [Beth
# Oliveira (page does not exist)") (Bàbá Paulo Ifatide) * [Paulo
# Vieira](/w/index.php?title=Paulo_Vieira&action=edit&redlink=1 "Paulo Vieira (page does not exist)") * [Rafa
# Rafuagi](/w/index.php?title=Rafa_Rafuagi&action=edit&redlink=1 "Rafa Rafuagi (page does not exist)") * [Rita
# Benneditto](/w/index.php?title=Rita_Benneditto&action=edit&redlink=1 "Rita Benneditto (page does not exist)") *
# [Roberta Sá](/wiki/Roberta_S%C3%A1 "Roberta Sá") * [Rogéria
# Holtz](/w/index.php?title=Rog%C3%A9ria_Holtz&action=edit&redlink=1 "Rogéria Holtz (page does not exist)") * [Sérgio
# Vaz](/w/index.php?title=S%C3%A9rgio_Vaz&action=edit&redlink=1 "Sérgio Vaz (page does not exist)") * [Thalma de
# Freitas](/wiki/Thalma_de_Freitas "Thalma de Freitas") * [Valdeck de
# Garanhuns](/w/index.php?title=Valdeck_de_Garanhuns&action=edit&redlink=1 "Valdeck de Garanhuns (page does not
# exist)") * [Valdir Calado](/w/index.php?title=Valdir_Calado&action=edit&redlink=1 "Valdir Calado (page does not
# exist)") (Mestre Dico) * [Vilma Melo](/w/index.php?title=Vilma_Melo&action=edit&redlink=1 "Vilma Melo (page does
# not exist)") * [Wallace Pato](/w/index.php?title=Wallace_Pato&action=edit&redlink=1 "Wallace Pato (page does not
# exist)") * [Associação dos Produtores
# Teatrais](/w/index.php?title=Associa%C3%A7%C3%A3o_dos_Produtores_Teatrais&action=edit&redlink=1 "Associação dos
# Produtores Teatrais (page does not exist)") * [Balé Folclórico da
# Bahia](/w/index.php?title=Bal%C3%A9_Folcl%C3%B3rico_da_Bahia&action=edit&redlink=1 "Balé Folclórico da Bahia (page
# does not exist)") * [Companhia Teatral Vem
# Viver](/w/index.php?title=Companhia_Teatral_Vem_Viver&action=edit&redlink=1 "Companhia Teatral Vem Viver (page does
# not exist)") * [Feira do Livro de Porto
# Alegre](/w/index.php?title=Feira_do_Livro_de_Porto_Alegre&action=edit&redlink=1 "Feira do Livro de Porto Alegre
# (page does not exist)") * [Festival Amazonas de Ópera](/wiki/Festival_Amazonas_de_%C3%93pera "Festival Amazonas de
# Ópera") * [Festival de Parintins](/wiki/Parintins_Festival "Parintins Festival") * [Grupo Corpo](/wiki/Grupo_Corpo
# "Grupo Corpo") * [Grupo Gira Dança](/w/index.php?title=Grupo_Gira_Dan%C3%A7a&action=edit&redlink=1 "Grupo Gira
# Dança (page does not exist)") * [Museu da Diversidade
# Sexual](/w/index.php?title=Museu_da_Diversidade_Sexual&action=edit&redlink=1 "Museu da Diversidade Sexual (page
# does not exist)") * [Museu da Língua Portuguesa](/wiki/Museu_da_L%C3%ADngua_Portuguesa "Museu da Língua
# Portuguesa") * [Museu dos Quilombos e Favelas Urbanos -
# Muquifu](/w/index.php?title=Museu_dos_Quilombos_e_Favelas_Urbanos_-_Muquifu&action=edit&redlink=1 "Museu dos
# Quilombos e Favelas Urbanos - Muquifu (page does not exist)") * [Ocupa
# MinC](/w/index.php?title=Ocupa_MinC&action=edit&redlink=1 "Ocupa MinC (page does not exist)") * [Organizações
# Globo](/wiki/Organiza%C3%A7%C3%B5es_Globo "Organizações Globo") * [Spetaculu - Escola de Arte e
# Tecnologia](/w/index.php?title=Spetaculu_-_Escola_de_Arte_e_Tecnologia&action=edit&redlink=1 "Spetaculu - Escola de
# Arte e Tecnologia (page does not exist)") |
#
# | [Authority control databases](/wiki/Help:Authority_control "Help:Authority control") [Edit this at
# Wikidata](https://www.wikidata.org/wiki/Q216450#identifiers "Edit this at Wikidata") | |
# | --- | --- |
# | International | * [ISNI](https://isni.org/isni/0000000114681685) * [VIAF](https://viaf.org/viaf/14968654) *
# [FAST](https://id.worldcat.org/fast/206968) *
# [WorldCat](https://id.oclc.org/worldcat/entity/E39PBJg4jkvpjvDbg6bYgRy8G3) |
# | National | * [Germany](https://d-nb.info/gnd/119022249) * [United
# States](https://id.loc.gov/authorities/n87117284) * [France](https://catalogue.bnf.fr/ark:/12148/cb13999885k) *
# [BnF data](https://data.bnf.fr/ark:/12148/cb13999885k) * [Italy](https://opac.sbn.it/nome/UBOV850079) *
# [Spain](https://datos.bne.es/resource/XX1088218) * [Netherlands](http://data.bibliotheken.nl/id/thes/p071981608) *
# [Norway](https://authority.bibsys.no/authority/rest/authorities/html/9050316) *
# [Chile](http://www.bncatalogo.cl/F?func=direct&local_base=red10&doc_number=000157687) *
# [Argentina](https://catalogo.bn.gov.ar/F/?func=direct&local_base=BNA10&doc_number=000042426) *
# [Korea](https://lod.nl.go.kr/resource/KAC2020N6852) *
# [Israel](https://www.nli.org.il/en/authorities/987007594420405171) *
# [Catalonia](https://cantic.bnc.cat/registre/981058518702206706) |
# | Artists | * [MusicBrainz](https://musicbrainz.org/artist/324b9329-7be6-491f-9ee1-65bfa10c7577) |
# | People | * [Deutsche Biographie](https://www.deutsche-biographie.de/119022249.html?language=en) *
# [DDB](https://www.deutsche-digitale-bibliothek.de/person/gnd/119022249) |
# | Other | * [IdRef](https://www.idref.fr/08071613X) * [SNAC](https://snaccooperative.org/ark:/99166/w67n4hns) |
#
# [Portals](/wiki/Wikipedia:Contents/Portals "Wikipedia:Contents/Portals"):
#
# * ![flag](//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/40px-Flag_of_Argentina.svg.png)
# [Argentina](/wiki/Portal:Argentina "Portal:Argentina")
# * ![](//upload.wikimedia.org/wikipedia/commons/thumb/3/37/Conga.svg/20px-Conga.svg.png) [Latin
# music](/wiki/Portal:Latin_music "Portal:Latin music")
#
# ![](https://en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1&usesul3=1)
#
# Retrieved from "<https://en.wikipedia.org/w/index.php?title=Mercedes_Sosa&oldid=1294833034>"
#
# [Categories](/wiki/Help:Category "Help:Category"):
#
# * [1935 births](/wiki/Category:1935_births "Category:1935 births")
# * [2009 deaths](/wiki/Category:2009_deaths "Category:2009 deaths")
# * [Latin Grammy Award winners](/wiki/Category:Latin_Grammy_Award_winners "Category:Latin Grammy Award winners")
# * [20th-century Argentine women singers](/wiki/Category:20th-century_Argentine_women_singers "Category:20th-century
# Argentine women singers")
# * [Argentine activists](/wiki/Category:Argentine_activists "Category:Argentine activists")
# * [Argentine women activists](/wiki/Category:Argentine_women_activists "Category:Argentine women activists")
# * [Argentine people of French descent](/wiki/Category:Argentine_people_of_French_descent "Category:Argentine people
# of French descent")
# * [Argentine people of Diaguita descent](/wiki/Category:Argentine_people_of_Diaguita_descent "Category:Argentine
# people of Diaguita descent")
# * [Argentine people of Quechua descent](/wiki/Category:Argentine_people_of_Quechua_descent "Category:Argentine
# people of Quechua descent")
# * [Deaths from kidney failure in Argentina](/wiki/Category:Deaths_from_kidney_failure_in_Argentina "Category:Deaths
# from kidney failure in Argentina")
# * [People from San Miguel de Tucumán](/wiki/Category:People_from_San_Miguel_de_Tucum%C3%A1n "Category:People from
# San Miguel de Tucumán")
# * [Nueva canción musicians](/wiki/Category:Nueva_canci%C3%B3n_musicians "Category:Nueva canción musicians")
# * [Bombo legüero players](/wiki/Category:Bombo_leg%C3%BCero_players "Category:Bombo legüero players")
# * [Latin Grammy Lifetime Achievement Award winners](/wiki/Category:Latin_Grammy_Lifetime_Achievement_Award_winners
# "Category:Latin Grammy Lifetime Achievement Award winners")
# * [Recipients of the Order of Cultural Merit
# (Brazil)](/wiki/Category:Recipients_of_the_Order_of_Cultural_Merit_(Brazil) "Category:Recipients of the Order of
# Cultural Merit (Brazil)")
# * [20th-century drummers](/wiki/Category:20th-century_drummers "Category:20th-century drummers")
# * [Women in Latin music](/wiki/Category:Women_in_Latin_music "Category:Women in Latin music")
#
# Hidden categories:
#
# * [All articles with dead external links](/wiki/Category:All_articles_with_dead_external_links "Category:All
# articles with dead external links")
# * [Articles with dead external links from June
# 2024](/wiki/Category:Articles_with_dead_external_links_from_June_2024 "Category:Articles with dead external links
# from June 2024")
# * [CS1 Spanish-language sources (es)](/wiki/Category:CS1_Spanish-language_sources_(es) "Category:CS1
# Spanish-language sources (es)")
# * [CS1 maint: numeric names: authors list](/wiki/Category:CS1_maint:_numeric_names:_authors_list "Category:CS1
# maint: numeric names: authors list")
# * [Webarchive template wayback links](/wiki/Category:Webarchive_template_wayback_links "Category:Webarchive
# template wayback links")
# * [Articles with German-language sources (de)](/wiki/Category:Articles_with_German-language_sources_(de)
# "Category:Articles with German-language sources (de)")
# * [Articles with short description](/wiki/Category:Articles_with_short_description "Category:Articles with short
# description")
# * [Short description is different from Wikidata](/wiki/Category:Short_description_is_different_from_Wikidata
# "Category:Short description is different from Wikidata")
# * [Wikipedia indefinitely move-protected pages](/wiki/Category:Wikipedia_indefinitely_move-protected_pages
# "Category:Wikipedia indefinitely move-protected pages")
# * [Use dmy dates from July 2023](/wiki/Category:Use_dmy_dates_from_July_2023 "Category:Use dmy dates from July
# 2023")
# * [Articles with hCards](/wiki/Category:Articles_with_hCards "Category:Articles with hCards")
# * [Pages with Latin American Spanish IPA](/wiki/Category:Pages_with_Latin_American_Spanish_IPA "Category:Pages with
# Latin American Spanish IPA")
# * [All articles with unsourced statements](/wiki/Category:All_articles_with_unsourced_statements "Category:All
# articles with unsourced statements")
# * [Articles with unsourced statements from December
# 2023](/wiki/Category:Articles_with_unsourced_statements_from_December_2023 "Category:Articles with unsourced
# statements from December 2023")
# * [Commons category link is on Wikidata](/wiki/Category:Commons_category_link_is_on_Wikidata "Category:Commons
# category link is on Wikidata")
#
# * This page was last edited on 10 June 2025, at 02:22 (UTC).
# * Text is available under the [Creative Commons Attribution-ShareAlike 4.0
# License](/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# "Wikipedia:Text of the Creative Commons Attribution-ShareAlike 4.0 International License");
#   additional terms may apply. By using this site, you agree to the [Terms of
# Use](https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# "foundation:Special:MyLanguage/Policy:Terms of Use") and [Privacy
# Policy](https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# "foundation:Special:MyLanguage/Policy:Privacy policy"). Wikipedia® is a registered trademark of the [Wikimedia
# Foundation, Inc.](https://wikimediafoundation.org/), a non-profit organization.
#
# * [Privacy policy](https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy)
# * [About Wikipedia](/wiki/Wikipedia:About)
# * [Disclaimers](/wiki/Wikipedia:General_disclaimer)
# * [Contact Wikipedia](//en.wikipedia.org/wiki/Wikipedia:Contact_us)
# ...
#       print(key + ":")
#       if key == "Personal Information":
#           # For Personal Information, we'll extract child details separately due to different structure
#           # Assuming that after "children include" there's a list with one name separated by commas.
#           _, _, children_details = value.partition("children include ")
#           _, _, name = children_details.rpartition(", ")
#           print(name)
#       else:
#           print(value)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Overview:
#
# Early Life:
#
# Musical Career:
# Besides her musical career, Sosa married three times; her children include Pedro Vargas, a film producer.
# Achievements:
#
# Legacy and Impact:
#
# Recognition:
#
# Personal Information:
#
#
# Out: ('', '', '')
# [Step 6: Duration 45.34 seconds| Input tokens: 25,506 | Output tokens: 1,886]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 7 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# [Step 7: Duration 2.36 seconds]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 35
#      32 question = "What is the favourite dessert of Elisabeth II of United Kingdom?"
#      33 prompt="How many studio albums were published by Mercedes Sosa between 2000 and 2009 (included)? You can use the latest 2022 version of english wikipedia."
# ---> 35 agent.run(prompt+system_prompt)
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/smolagents/agents.py:411, in MultiStepAgent.run(self, task, stream, reset, images, additional_args, max_steps)
#     408 run_start_time = time.time()
#     409 # Outputs are returned only at the end. We only look at the last step.
# --> 411 steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     412 assert isinstance(steps[-1], FinalAnswerStep)
#     413 output = steps[-1].output
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/smolagents/agents.py:485, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     479 action_step = ActionStep(
#     480     step_number=self.step_number,
#     481     timing=Timing(start_time=action_step_start_time),
#     482     observations_images=images,
#     483 )
#     484 try:
# --> 485     for el in self._execute_step(action_step):
#     486         yield el
#     487     final_answer = el
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/smolagents/agents.py:507, in MultiStepAgent._execute_step(self, memory_step)
#     505 def _execute_step(self, memory_step: ActionStep) -> Generator[ChatMessageStreamDelta | FinalOutput]:
#     506     self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
# --> 507     for el in self._step_stream(memory_step):
#     508         final_answer = el
#     509         if isinstance(el, ChatMessageStreamDelta):
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/smolagents/agents.py:1611, in CodeAgent._step_stream(self, memory_step)
#    1609     output_text = chat_message.content
#    1610 else:
# -> 1611     chat_message: ChatMessage = self.model.generate(
#    1612         input_messages,
#    1613         stop_sequences=["<end_code>", "Observation:", "Calling tools:"],
#    1614         **additional_args,
#    1615     )
#    1616     memory_step.model_output_message = chat_message
#    1617     output_text = chat_message.content
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/smolagents/models.py:1054, in LiteLLMModel.generate(self, messages, stop_sequences, response_format, tools_to_call_from, **kwargs)
#    1033 def generate(
#    1034     self,
#    1035     messages: list[dict[str, str | list[dict]] | ChatMessage],
#    (...)   1039     **kwargs,
#    1040 ) -> ChatMessage:
#    1041     completion_kwargs = self._prepare_completion_kwargs(
#    1042         messages=messages,
#    1043         stop_sequences=stop_sequences,
#    (...)   1051         **kwargs,
#    1052     )
# -> 1054     response = self.client.completion(**completion_kwargs)
#    1056     self._last_input_token_count = response.usage.prompt_tokens
#    1057     self._last_output_token_count = response.usage.completion_tokens
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/utils.py:1163, in client.<locals>.wrapper(*args, **kwargs)
#    1161         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1162 # MODEL CALL
# -> 1163 result = original_function(*args, **kwargs)
#    1164 end_time = datetime.datetime.now()
#    1165 if "stream" in kwargs and kwargs["stream"] is True:
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/main.py:2993, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    2979     api_base = (
#    2980         litellm.api_base
#    2981         or api_base
#    2982         or get_secret("OLLAMA_API_BASE")
#    2983         or "http://localhost:11434"
#    2984     )
#    2986     api_key = (
#    2987         api_key
#    2988         or litellm.ollama_key
#    2989         or os.environ.get("OLLAMA_API_KEY")
#    2990         or litellm.api_key
#    2991     )
# -> 2993     response = base_llm_http_handler.completion(
#    2994         model=model,
#    2995         stream=stream,
#    2996         messages=messages,
#    2997         acompletion=acompletion,
#    2998         api_base=api_base,
#    2999         model_response=model_response,
#    3000         optional_params=optional_params,
#    3001         litellm_params=litellm_params,
#    3002         custom_llm_provider="ollama_chat",
#    3003         timeout=timeout,
#    3004         headers=headers,
#    3005         encoding=encoding,
#    3006         api_key=api_key,
#    3007         logging_obj=logging,  # model call logging done inside the class as we make need to modify I/O to fit aleph alpha's requirements
#    3008         client=client,
#    3009     )
#    3011 elif custom_llm_provider == "triton":
#    3012     api_base = litellm.api_base or api_base
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:455, in BaseLLMHTTPHandler.completion(self, model, messages, api_base, custom_llm_provider, model_response, encoding, logging_obj, optional_params, timeout, litellm_params, acompletion, stream, fake_stream, api_key, headers, client, provider_config)
#     452 else:
#     453     sync_httpx_client = client
# --> 455 response = self._make_common_sync_call(
#     456     sync_httpx_client=sync_httpx_client,
#     457     provider_config=provider_config,
#     458     api_base=api_base,
#     459     headers=headers,
#     460     data=data,
#     461     signed_json_body=signed_json_body,
#     462     timeout=timeout,
#     463     litellm_params=litellm_params,
#     464     logging_obj=logging_obj,
#     465 )
#     466 return provider_config.transform_response(
#     467     model=model,
#     468     raw_response=response,
#    (...)    477     json_mode=json_mode,
#     478 )
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:160, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     158 for i in range(max(max_retry_on_unprocessable_entity_error, 1)):
#     159     try:
# --> 160         response = sync_httpx_client.post(
#     161             url=api_base,
#     162             headers=headers,
#     163             data=(
#     164                 signed_json_body
#     165                 if signed_json_body is not None
#     166                 else json.dumps(data)
#     167             ),
#     168             timeout=timeout,
#     169             stream=stream,
#     170             logging_obj=logging_obj,
#     171         )
#     172     except httpx.HTTPStatusError as e:
#     173         hit_max_retry = i + 1 == max_retry_on_unprocessable_entity_error
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/llms/custom_httpx/http_handler.py:685, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     681 else:
#     682     req = self.client.build_request(
#     683         "POST", url, data=data, json=json, params=params, headers=headers, files=files, content=content  # type: ignore
#     684     )
# --> 685 response = self.client.send(req, stream=stream)
#     686 response.raise_for_status()
#     687 return response
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Selenium agent (WIP)

# %%
import argparse
from io import BytesIO
from time import sleep

import helium
from dotenv import load_dotenv
from PIL import Image
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

from smolagents import CodeAgent, DuckDuckGoSearchTool, tool, LiteLLMModel
from smolagents.agents import ActionStep
from smolagents.cli import load_model
import os

os.environ["OPENAI_API_KEY"] = "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"


alfred_guest_list_request = """
I am Alfred, the butler of Wayne Manor, responsible for verifying the identity of guests at party. A superhero has arrived at the entrance claiming to be Wonder Woman, but I need to confirm if she is who she says she is.
Please search for images of Wonder Woman and generate a detailed visual description based on those images. Additionally, navigate to Wikipedia to gather key details about her appearance. With this information, I can determine whether to grant her access to the event.
"""


def parse_arguments():
    parser = argparse.ArgumentParser(description="Run a web browser automation script with a specified model.")
    parser.add_argument(
        "prompt",
        type=str,
        nargs="?",  # Makes it optional
        default=alfred_guest_list_request,
        help="The prompt to run with the agent",
    )
    parser.add_argument(
        "--model-type",
        type=str,
        default="LiteLLMModel",
        help="The model type to use (e.g., OpenAIServerModel, LiteLLMModel, TransformersModel, InferenceClientModel)",
    )
    parser.add_argument(
        "--model-id",
        type=str,
        default="gpt-4o",
        help="The model ID to use for the specified model type",
    )
    return parser.parse_args()


def save_screenshot(memory_step: ActionStep, agent: CodeAgent) -> None:
    sleep(1.0)  # Let JavaScript animations happen before taking the screenshot
    driver = helium.get_driver()
    current_step = memory_step.step_number
    if driver is not None:
        for previous_memory_step in agent.memory.steps:  # Remove previous screenshots from logs for lean processing
            if isinstance(previous_memory_step, ActionStep) and previous_memory_step.step_number <= current_step - 2:
                previous_memory_step.observations_images = None
        png_bytes = driver.get_screenshot_as_png()
        image = Image.open(BytesIO(png_bytes))
        print(f"Captured a browser screenshot: {image.size} pixels")
        memory_step.observations_images = [image.copy()]  # Create a copy to ensure it persists, important!

    # Update observations with current URL
    url_info = f"Current url: {driver.current_url}"
    memory_step.observations = (
        url_info if memory_step.observations is None else memory_step.observations + "\n" + url_info
    )
    return


@tool
def search_item_ctrl_f(text: str, nth_result: int = 1) -> str:
    """
    Searches for text on the current page via Ctrl + F and jumps to the nth occurrence.
    Args:
        text: The text to search for
        nth_result: Which occurrence to jump to (default: 1)
    """
    elements = driver.find_elements(By.XPATH, f"//*[contains(text(), '{text}')]")
    if nth_result > len(elements):
        raise Exception(f"Match n°{nth_result} not found (only {len(elements)} matches found)")
    result = f"Found {len(elements)} matches for '{text}'."
    elem = elements[nth_result - 1]
    driver.execute_script("arguments[0].scrollIntoView(true);", elem)
    result += f"Focused on element {nth_result} of {len(elements)}"
    return result


@tool
def go_back() -> None:
    """Goes back to previous page."""
    driver.back()


@tool
def close_popups() -> str:
    """
    Closes any visible modal or pop-up on the page. Use this to dismiss pop-up windows! This does not work on cookie consent banners.
    """
    webdriver.ActionChains(driver).send_keys(Keys.ESCAPE).perform()


def initialize_driver():
    """Initialize the Selenium WebDriver."""
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument("--force-device-scale-factor=1")
    chrome_options.add_argument("--window-size=1000,1350")
    chrome_options.add_argument("--disable-pdf-viewer")
    chrome_options.add_argument("--window-position=0,0")
    return helium.start_chrome(headless=False, options=chrome_options)


def initialize_agent(model):
    """Initialize the CodeAgent with the specified model."""
    return CodeAgent(
        tools=[DuckDuckGoSearchTool(), go_back, close_popups, search_item_ctrl_f],
        model=model,
        additional_authorized_imports=["helium"],
        step_callbacks=[save_screenshot],
        max_steps=20,
        verbosity_level=2,
    )


helium_instructions = """
Use your web_search tool when you want to get Google search results.
Then you can use helium to access websites. Don't use helium for Google search, only for navigating websites!
Don't bother about the helium driver, it's already managed.
We've already ran "from helium import *"
Then you can go to pages! Don't go directly to specific urls, only use links from google search.
Code:
```py
go_to('github.com/trending')
```<end_code>
You can directly click clickable elements by inputting the text that appears on them.
Code:
```py
click("Top products")
```<end_code>
If it's a link:
Code:
```py
click(Link("Top products"))
```<end_code>
If you try to interact with an element and it's not found, you'll get a LookupError.
In general stop your action after each button click to see what happens on your screenshot.
Never try to login in a page.
To scroll up or down, use scroll_down or scroll_up with as an argument the number of pixels to scroll from.
Code:
```py
scroll_down(num_pixels=1200) # This will scroll one viewport down
```<end_code>
When you have pop-ups with a cross icon to close, don't try to click the close icon by finding its element or targeting an 'X' element (this most often fails).
Just use your built-in tool `close_popups` to close them:
Code:
```py
close_popups()
```<end_code>
You can use .exists() to check for the existence of an element. For example:
Code:
```py
if Text('Accept cookies?').exists():
    click('I accept')
```<end_code>
Proceed in several steps rather than trying to solve the task in one shot.
And at the end, only when you have your answer, return your final answer.
Code:
```py
final_answer("YOUR_ANSWER_HERE")
```<end_code>
If pages seem stuck on loading, you might have to wait, for instance `import time` and run `time.sleep(5.0)`. But don't overuse this!
To list elements on page, DO NOT try code-based element searches like 'contributors = find_all(S("ol > li"))': just look at the latest screenshot you have and read it visually, or use your tool search_item_ctrl_f.
Of course, you can act on buttons like a user would do when navigating.
After each code blob you write, you will be automatically provided with an updated screenshot of the browser and the current browser url.
But beware that the screenshot will only be taken at the end of the whole action, it won't see intermediate states.
Don't kill the browser.
When you have modals or cookie banners on screen, you should get rid of them before you can click anything else.
"""


def main():
    # Load environment variables
    # load_dotenv()

    # # Parse command line arguments
    # args = parse_arguments()

    # Initialize the model based on the provided arguments
    #model = load_model(args.model_type, args.model_id)
    # model = load_model(
    #     model_type='OpenAIServerModel', 
    #     model_id='mistralai/devstral-small:free',
    #     api_key=os.environ["OPENAI_API_KEY"],
    #     api_base='https://openrouter.ai/api/v1'
    # )

    # model = load_model(
    #     model_type='LiteLLMModel', 
    #     model_id='ollama_chat/qwen2:7b',
    #     api_base='http://127.0.0.1:11434',
    # )

    model = LiteLLMModel(
    model_id='ollama_chat/qwen2:7b',
    api_base='http://127.0.0.1:11434',
    flatten_messages_as_text=False
)

    global driver
    driver = initialize_driver()
    agent = initialize_agent(model)

    # Run the agent with the provided prompt
    agent.python_executor("from helium import *")
    prompt="How many studio albums were published by Mercedes Sosa between 2000 and 2009 (included)? You can use the latest 2022 version of english wikipedia."
    agent.run(prompt + helium_instructions)

main()
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ How many studio albums were published by Mercedes Sosa between 2000 and 2009 (included)? You can use the latest │
# │ 2022 version of english wikipedia.                                                                              │
# │ Use your web_search tool when you want to get Google search results.                                            │
# │ Then you can use helium to access websites. Don't use helium for Google search, only for navigating websites!   │
# │ Don't bother about the helium driver, it's already managed.                                                     │
# │ We've already ran "from helium import *"                                                                        │
# │ Then you can go to pages! Don't go directly to specific urls, only use links from google search.                │
# │ Code:                                                                                                           │
# │ ```py                                                                                                           │
# │ go_to('github.com/trending')                                                                                    │
# │ ```<end_code>                                                                                                   │
# │ You can directly click clickable elements by inputting the text that appears on them.                           │
# │ Code:                                                                                                           │
# │ ```py                                                                                                           │
# │ click("Top products")                                                                                           │
# │ ```<end_code>                                                                                                   │
# │ If it's a link:                                                                                                 │
# │ Code:                                                                                                           │
# │ ```py                                                                                                           │
# │ click(Link("Top products"))                                                                                     │
# │ ```<end_code>                                                                                                   │
# │ If you try to interact with an element and it's not found, you'll get a LookupError.                            │
# │ In general stop your action after each button click to see what happens on your screenshot.                     │
# │ Never try to login in a page.                                                                                   │
# │ To scroll up or down, use scroll_down or scroll_up with as an argument the number of pixels to scroll from.     │
# │ Code:                                                                                                           │
# │ ```py                                                                                                           │
# │ scroll_down(num_pixels=1200) # This will scroll one viewport down                                               │
# │ ```<end_code>                                                                                                   │
# │ When you have pop-ups with a cross icon to close, don't try to click the close icon by finding its element or   │
# │ targeting an 'X' element (this most often fails).                                                               │
# │ Just use your built-in tool `close_popups` to close them:                                                       │
# │ Code:                                                                                                           │
# │ ```py                                                                                                           │
# │ close_popups()                                                                                                  │
# │ ```<end_code>                                                                                                   │
# │ You can use .exists() to check for the existence of an element. For example:                                    │
# │ Code:                                                                                                           │
# │ ```py                                                                                                           │
# │ if Text('Accept cookies?').exists():                                                                            │
# │     click('I accept')                                                                                           │
# │ ```<end_code>                                                                                                   │
# │ Proceed in several steps rather than trying to solve the task in one shot.                                      │
# │ And at the end, only when you have your answer, return your final answer.                                       │
# │ Code:                                                                                                           │
# │ ```py                                                                                                           │
# │ final_answer("YOUR_ANSWER_HERE")                                                                                │
# │ ```<end_code>                                                                                                   │
# │ If pages seem stuck on loading, you might have to wait, for instance `import time` and run `time.sleep(5.0)`.   │
# │ But don't overuse this!                                                                                         │
# │ To list elements on page, DO NOT try code-based element searches like 'contributors = find_all(S("ol > li"))':  │
# │ just look at the latest screenshot you have and read it visually, or use your tool search_item_ctrl_f.          │
# │ Of course, you can act on buttons like a user would do when navigating.                                         │
# │ After each code blob you write, you will be automatically provided with an updated screenshot of the browser    │
# │ and the current browser url.                                                                                    │
# │ But beware that the screenshot will only be taken at the end of the whole action, it won't see intermediate     │
# │ states.                                                                                                         │
# │ Don't kill the browser.                                                                                         │
# │ When you have modals or cookie banners on screen, you should get rid of them before you can click anything      │
# │ else.                                                                                                           │
# │                                                                                                                 │
# ╰─ LiteLLMModel - ollama_chat/qwen2:7b ───────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# Error in generating model output:
# litellm.APIConnectionError: Ollama_chatException - {"error":"json: cannot unmarshal array into Go struct field
# ChatRequest.messages.content of type string"}
# Captured a browser screenshot: (1000, 737) pixels
# [Step 1: Duration 0.07 seconds]
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:160, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     159 try:
# --> 160     response = sync_httpx_client.post(
#     161         url=api_base,
#     162         headers=headers,
#     163         data=(
#     164             signed_json_body
#     165             if signed_json_body is not None
#     166             else json.dumps(data)
#     167         ),
#     168         timeout=timeout,
#     169         stream=stream,
#     170         logging_obj=logging_obj,
#     171     )
#     172 except httpx.HTTPStatusError as e:
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/llms/custom_httpx/http_handler.py:704, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     703     setattr(e, "status_code", e.response.status_code)
# --> 704     raise e
#     705 except Exception as e:
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/llms/custom_httpx/http_handler.py:686, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     685 response = self.client.send(req, stream=stream)
# --> 686 response.raise_for_status()
#     687 return response
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '400 Bad Request' for url 'http://127.0.0.1:11434/api/chat'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/400
#
# During handling of the above exception, another exception occurred:
#
# OllamaError                               Traceback (most recent call last)
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/main.py:2993, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    2986     api_key = (
#    2987         api_key
#    2988         or litellm.ollama_key
#    2989         or os.environ.get("OLLAMA_API_KEY")
#    2990         or litellm.api_key
#    2991     )
# -> 2993     response = base_llm_http_handler.completion(
#    2994         model=model,
#    2995         stream=stream,
#    2996         messages=messages,
#    2997         acompletion=acompletion,
#    2998         api_base=api_base,
#    2999         model_response=model_response,
#    3000         optional_params=optional_params,
#    3001         litellm_params=litellm_params,
#    3002         custom_llm_provider="ollama_chat",
#    3003         timeout=timeout,
#    3004         headers=headers,
#    3005         encoding=encoding,
#    3006         api_key=api_key,
#    3007         logging_obj=logging,  # model call logging done inside the class as we make need to modify I/O to fit aleph alpha's requirements
#    3008         client=client,
#    3009     )
#    3011 elif custom_llm_provider == "triton":
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:455, in BaseLLMHTTPHandler.completion(self, model, messages, api_base, custom_llm_provider, model_response, encoding, logging_obj, optional_params, timeout, litellm_params, acompletion, stream, fake_stream, api_key, headers, client, provider_config)
#     453     sync_httpx_client = client
# --> 455 response = self._make_common_sync_call(
#     456     sync_httpx_client=sync_httpx_client,
#     457     provider_config=provider_config,
#     458     api_base=api_base,
#     459     headers=headers,
#     460     data=data,
#     461     signed_json_body=signed_json_body,
#     462     timeout=timeout,
#     463     litellm_params=litellm_params,
#     464     logging_obj=logging_obj,
#     465 )
#     466 return provider_config.transform_response(
#     467     model=model,
#     468     raw_response=response,
#    (...)    477     json_mode=json_mode,
#     478 )
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:185, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     184     else:
# --> 185         raise self._handle_error(e=e, provider_config=provider_config)
#     186 except Exception as e:
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:2221, in BaseLLMHTTPHandler._handle_error(self, e, provider_config)
#    2219     error_headers = {}
# -> 2221 raise provider_config.get_error_class(
#    2222     error_message=error_text,
#    2223     status_code=status_code,
#    2224     headers=error_headers,
#    2225 )
#
# OllamaError: {"error":"json: cannot unmarshal array into Go struct field ChatRequest.messages.content of type string"}
#
# During handling of the above exception, another exception occurred:
#
# APIConnectionError                        Traceback (most recent call last)
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/smolagents/agents.py:1611, in CodeAgent._step_stream(self, memory_step)
#    1610 else:
# -> 1611     chat_message: ChatMessage = self.model.generate(
#    1612         input_messages,
#    1613         stop_sequences=["<end_code>", "Observation:", "Calling tools:"],
#    1614         **additional_args,
#    1615     )
#    1616     memory_step.model_output_message = chat_message
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/smolagents/models.py:1054, in LiteLLMModel.generate(self, messages, stop_sequences, response_format, tools_to_call_from, **kwargs)
#    1041 completion_kwargs = self._prepare_completion_kwargs(
#    1042     messages=messages,
#    1043     stop_sequences=stop_sequences,
#    (...)   1051     **kwargs,
#    1052 )
# -> 1054 response = self.client.completion(**completion_kwargs)
#    1056 self._last_input_token_count = response.usage.prompt_tokens
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/utils.py:1285, in client.<locals>.wrapper(*args, **kwargs)
#    1282     logging_obj.failure_handler(
#    1283         e, traceback_exception, start_time, end_time
#    1284     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1285 raise e
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/utils.py:1163, in client.<locals>.wrapper(*args, **kwargs)
#    1162 # MODEL CALL
# -> 1163 result = original_function(*args, **kwargs)
#    1164 end_time = datetime.datetime.now()
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/main.py:3273, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3271 except Exception as e:
#    3272     ## Map to OpenAI Exception
# -> 3273     raise exception_type(
#    3274         model=model,
#    3275         custom_llm_provider=custom_llm_provider,
#    3276         original_exception=e,
#    3277         completion_kwargs=args,
#    3278         extra_kwargs=kwargs,
#    3279     )
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2271, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2270     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2271     raise e
#    2272 else:
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2240, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2239 if hasattr(original_exception, "request"):
# -> 2240     raise APIConnectionError(
#    2241         message="{} - {}".format(exception_provider, error_str),
#    2242         llm_provider=custom_llm_provider,
#    2243         model=model,
#    2244         request=original_exception.request,
#    2245     )
#    2246 else:
#
# APIConnectionError: litellm.APIConnectionError: Ollama_chatException - {"error":"json: cannot unmarshal array into Go struct field ChatRequest.messages.content of type string"}
#
# The above exception was the direct cause of the following exception:
#
# AgentGenerationError                      Traceback (most recent call last)
# Cell In[13], line 218
#     215     prompt="How many studio albums were published by Mercedes Sosa between 2000 and 2009 (included)? You can use the latest 2022 version of english wikipedia."
#     216     agent.run(prompt + helium_instructions)
# --> 218 main()
#
# Cell In[13], line 216, in main()
#     214 agent.python_executor("from helium import *")
#     215 prompt="How many studio albums were published by Mercedes Sosa between 2000 and 2009 (included)? You can use the latest 2022 version of english wikipedia."
# --> 216 agent.run(prompt + helium_instructions)
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/smolagents/agents.py:411, in MultiStepAgent.run(self, task, stream, reset, images, additional_args, max_steps)
#     408 run_start_time = time.time()
#     409 # Outputs are returned only at the end. We only look at the last step.
# --> 411 steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     412 assert isinstance(steps[-1], FinalAnswerStep)
#     413 output = steps[-1].output
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/smolagents/agents.py:490, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     487     final_answer = el
#     488 except AgentGenerationError as e:
#     489     # Agent generation errors are not caused by a Model error but an implementation error: so we should raise them and exit.
# --> 490     raise e
#     491 except AgentError as e:
#     492     # Other AgentError types are caused by the Model, so we should log them and iterate.
#     493     action_step.error = e
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/smolagents/agents.py:485, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     479 action_step = ActionStep(
#     480     step_number=self.step_number,
#     481     timing=Timing(start_time=action_step_start_time),
#     482     observations_images=images,
#     483 )
#     484 try:
# --> 485     for el in self._execute_step(action_step):
#     486         yield el
#     487     final_answer = el
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/smolagents/agents.py:507, in MultiStepAgent._execute_step(self, memory_step)
#     505 def _execute_step(self, memory_step: ActionStep) -> Generator[ChatMessageStreamDelta | FinalOutput]:
#     506     self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
# --> 507     for el in self._step_stream(memory_step):
#     508         final_answer = el
#     509         if isinstance(el, ChatMessageStreamDelta):
#
# File ~/Documents/Telecom/hackathon-huggingface/.venv/lib/python3.13/site-packages/smolagents/agents.py:1633, in CodeAgent._step_stream(self, memory_step)
#    1631     memory_step.model_output = output_text
#    1632 except Exception as e:
# -> 1633     raise AgentGenerationError(f"Error in generating model output:\n{e}", self.logger) from e
#    1635 ### Parse output ###
#    1636 try:
#
# AgentGenerationError: Error in generating model output:
# litellm.APIConnectionError: Ollama_chatException - {"error":"json: cannot unmarshal array into Go struct field ChatRequest.messages.content of type string"}
